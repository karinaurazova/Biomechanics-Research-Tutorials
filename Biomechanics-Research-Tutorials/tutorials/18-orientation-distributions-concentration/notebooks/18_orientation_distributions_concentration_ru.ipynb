# %% [markdown]
# # Tutorial 18 — Распределения ориентаций и параметры концентрации
#
# Этот notebook запускает основной синтетический benchmark ориентаций.

# %%
from pathlib import Path
import sys


def _find_repository_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "pyproject.toml").exists() and (candidate / "src").exists():
            return candidate
    raise RuntimeError("Repository root was not found")


REPOSITORY_ROOT = _find_repository_root(Path.cwd())
SOURCE_DIRECTORY = REPOSITORY_ROOT / "src"
if str(SOURCE_DIRECTORY) not in sys.path:
    sys.path.insert(0, str(SOURCE_DIRECTORY))

import biomechanics_tutorials
Path(biomechanics_tutorials.__file__).resolve()

# %%
LANGUAGE = "ru"
from biomechanics_tutorials.orientation_distributions import build_synthetic_orientation_dataset, benchmark_modalities

dataset = build_synthetic_orientation_dataset()
results, centers, densities = benchmark_modalities(dataset)
results

# %%
from pathlib import Path
import subprocess
import sys

tutorial_dir = REPOSITORY_ROOT / "tutorials" / "18-orientation-distributions-concentration"
subprocess.run([sys.executable, str(tutorial_dir / "reproduce.py")], check=True)
print("done")
