# %% [markdown]
# # Tutorial 22 — RVE-гомогенизация
#
# Этот notebook запускает базовый workflow периодической гомогенизации.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
while not (ROOT / "src" / "biomechanics_tutorials").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
from biomechanics_tutorials.rve_homogenization import homogenize_rve, stiffness_summary
result = homogenize_rve(nx=10, ny=10, seed=22)
stiffness_summary(result.periodic_stiffness, "periodic")

# %%
result.periodic_stiffness

# %% [markdown]
# Периодическую жёсткость нужно интерпретировать вместе с оценками Фойгта/Рейсса и ошибкой Хилла--Манделя.
