# %% [markdown]
# # Tutorial 25 — Sensitivity Analysis and Uncertainty Quantification
# Run the reproducible benchmark and inspect Monte Carlo, Sobol, Morris and posterior diagnostics.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
if (ROOT / 'src').exists(): sys.path.insert(0, str(ROOT / 'src'))
from biomechanics_tutorials.sensitivity_uncertainty import run_full_uq
result = run_full_uq(seed=25, n_mc=1024, n_sobol=512)
result['reliability']

# %% [markdown]
# Use `../reproduce.py` to regenerate all figures, GIF animations and tables.
