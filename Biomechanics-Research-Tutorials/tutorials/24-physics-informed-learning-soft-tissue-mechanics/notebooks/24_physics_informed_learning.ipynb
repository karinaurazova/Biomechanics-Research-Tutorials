# %% [markdown]
# # Tutorial 24 — Physics-Informed Learning

# %% [markdown]
# This notebook reproduces the main synthetic benchmark.

# %%
from biomechanics_tutorials.physics_informed_learning import generate_bar_dataset, run_case_suite, evaluate_prediction

data = generate_bar_dataset()
cases = run_case_suite(data)
{name: evaluate_prediction(data, pred) for name, pred in cases.items()}
