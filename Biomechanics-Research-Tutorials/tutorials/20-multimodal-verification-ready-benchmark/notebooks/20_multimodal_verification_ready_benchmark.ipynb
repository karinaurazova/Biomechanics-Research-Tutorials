# %% [markdown]
# # Tutorial 20 — Multimodal synthetic benchmark
#
# Run the cells to obtain the full pipeline and main metrics.

# %%
from __future__ import annotations

import sys
from pathlib import Path


def _find_repository_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'pyproject.toml').exists() and (candidate / 'src').exists():
            return candidate
    raise RuntimeError('Could not find repository root.')


NOTEBOOK_PATH = Path.cwd()
REPOSITORY_ROOT = _find_repository_root(NOTEBOOK_PATH)
SOURCE_DIRECTORY = REPOSITORY_ROOT / "src"
if str(SOURCE_DIRECTORY) not in sys.path:
    sys.path.insert(0, str(SOURCE_DIRECTORY))

import biomechanics_tutorials
print(Path(biomechanics_tutorials.__file__).resolve())

# %%
LANGUAGE = "en"
from biomechanics_tutorials.multimodal_benchmark import run_full_benchmark

result = run_full_benchmark(seed=20)
print('segmentation rows:', len(result.segmentation_metrics))
print('orientation rows:', len(result.orientation_metrics))
print('parameter scenarios:', len(result.parameter_results))

# %%
for row in result.error_budget:
    print(row)

# %%
best = min(result.parameter_results, key=lambda row: row['relative_parameter_error'])
print(best)
