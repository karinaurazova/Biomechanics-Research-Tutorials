# %% [markdown]
# # Tutorial 23 — Surrogate-моделирование
# Запустите reproduction script и изучите метрики/рисунки.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
while not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
from biomechanics_tutorials.surrogate_modeling import generate_surrogate_dataset, train_test_split, fit_ridge_surrogate, predict, regression_metrics
d = generate_surrogate_dataset(600)
tr, te = train_test_split(d.features.shape[0])
model = fit_ridge_surrogate(d.features[tr], d.targets[tr], basis='quadratic')
regression_metrics(d.targets[te], predict(model, d.features[te]))
